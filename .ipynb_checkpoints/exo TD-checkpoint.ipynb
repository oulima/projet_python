# %%
nom=['Steven','Oumar','Zak','Fred','David','Marianna','Myriam','Lochlean']
prenom='Fred'
prenom1='David'
for elem in nom:
    if elem == prenom or elem == prenom1:
        print("C'est bien mon prenom ",elem)
    else:
        print("Ce n'est pas moi ",elem)
# Out:
# Ce n'est pas moi  Steven
# Ce n'est pas moi  Oumar
# Ce n'est pas moi  Zak
# C'est bien mon prenom  Fred
# C'est bien mon prenom  David
# Ce n'est pas moi  Marianna
# Ce n'est pas moi  Myriam
# Ce n'est pas moi  Lochlean

# %%
i=0
while i<=100:
    print("Je ne dois laisser ma place assise aux personnes agées",i)
    i=i+1
# Out:
# Je ne dois laisser ma place assise aux personnes agées 0
# Je ne dois laisser ma place assise aux personnes agées 1
# Je ne dois laisser ma place assise aux personnes agées 2
# Je ne dois laisser ma place assise aux personnes agées 3
# Je ne dois laisser ma place assise aux personnes agées 4
# Je ne dois laisser ma place assise aux personnes agées 5
# Je ne dois laisser ma place assise aux personnes agées 6
# Je ne dois laisser ma place assise aux personnes agées 7
# Je ne dois laisser ma place assise aux personnes agées 8
# Je ne dois laisser ma place assise aux personnes agées 9
# Je ne dois laisser ma place assise aux personnes agées 10
# Je ne dois laisser ma place assise aux personnes agées 11
# Je ne dois laisser ma place assise aux personnes agées 12
# Je ne dois laisser ma place assise aux personnes agées 13
# Je ne dois laisser ma place assise aux personnes agées 14
# Je ne dois laisser ma place assise aux personnes agées 15
# ...

# %%
chiffre=0
i=1

while chiffre<1000:
    if i%2 == 0:
      chiffre = chiffre+200
    print (i,chiffre)
    i=i+1
# Out:
# 1 0
# 2 200
# 3 200
# 4 400
# 5 400
# 6 600
# 7 600
# 8 800
# 9 800
# 10 1000

# %%
from random import randint
import random
k=0
montant=1000
while montant>750 and k<=50:
    i=randint(1,6)
    if i==6:
        montant+=20
    else:
        montant-=10
    k=k+1
    restant=1000-montant
    print('perdu tu as fait : ',i, 'numero partie :  ',k,  'il te reste : ',montant)
# Out:
# perdu tu as fait :  3 numero partie :   1 il te reste :  990
# perdu tu as fait :  1 numero partie :   2 il te reste :  980
# perdu tu as fait :  1 numero partie :   3 il te reste :  970
# perdu tu as fait :  3 numero partie :   4 il te reste :  960
# perdu tu as fait :  3 numero partie :   5 il te reste :  950
# perdu tu as fait :  2 numero partie :   6 il te reste :  940
# perdu tu as fait :  6 numero partie :   7 il te reste :  960
# perdu tu as fait :  3 numero partie :   8 il te reste :  950
# perdu tu as fait :  2 numero partie :   9 il te reste :  940
# perdu tu as fait :  3 numero partie :   10 il te reste :  930
# perdu tu as fait :  4 numero partie :   11 il te reste :  920
# perdu tu as fait :  1 numero partie :   12 il te reste :  910
# perdu tu as fait :  5 numero partie :   13 il te reste :  900
# perdu tu as fait :  4 numero partie :   14 il te reste :  890
# perdu tu as fait :  1 numero partie :   15 il te reste :  880
# ...

# %%
DICTIONNAIRE
